# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import drive

# %%
drive.mount('/content/drive')
img = cv2.imread('/content/drive/MyDrive/Trabalho3/matas.jpg')
cv2_imshow(img)
cp = img.copy()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=750x612>

# %% [markdown]
# **Foto original**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# b, g, r = cv2.split(img)
# cv2_imshow(g)

# # Calcule o histograma
# histogram, bin_edges = np.histogram(cp, bins=256, range=(0, 256))

# # Plote o histograma
# plt.figure(figsize=(8, 6))
# plt.title('Histograma da Escala de Verde')
# plt.xlabel('Valor do Pixel')
# plt.ylabel('Frequência')
# plt.plot(bin_edges[0:-1], histogram, color='green')
# plt.show()

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
  hist = cv2.calcHist([cp], [i], None, [256], [0, 256])
  plt.plot(hist, color=col)
  plt.xlim([0, 256])

plt.show()

# %% [markdown]
# **Histograma da Imagem das Matas**

# %%
for i in range(cp.shape[0]):
  for j in range(cp.shape[1]):
    b, g, r = cp[i, j]
    if r > 140:
      cp[i, j] = (g+1, 50, g+1)
    else:
      cp[i,j] = (g+1, g+1, g-1)

cv2_imshow(cp)
# Out:
# <PIL.Image.Image image mode=RGB size=750x612>

# %% [markdown]
# **A área roxa busca identificar a área desmatada, enquanto que a cinza, a área verde.**

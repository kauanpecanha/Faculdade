# %%
#                   objetivos
#                         contar a quantidade de carros que trafegaram - check
#                         armazenar todos os carros em um repositório - check
#                         fazer mapa de calor de acordo com a quantidade de carros que ali passaram - função do cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import seaborn as sns

drive.mount('/content/drive/')

video = cv2.VideoCapture('/content/drive/MyDrive/One/video.mp4') # 2914 frames
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2

drive.mount('/content/drive/')

video = cv2.VideoCapture('/content/drive/MyDrive/One/video.mp4') # 2914 frames

contador = 0
cars = []
while(video.isOpened()):

  ret, frame = video.read()

  if not ret:
    break

  img = frame[int(0.65 * frame.shape[0]):frame.shape[0], 90:frame.shape[1]-100]
  contador += 1

  if(contador % 4 == 0):

    # testImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # diferenca = cv2.absdiff(testImage, mainImage)

    _, lim = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

    gauss = cv2.GaussianBlur(lim, (11, 11), 0)

    # canny = cv2.Canny(gauss, 30, 150, 3)

    contornos, _ = cv2.findContours(gauss.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.drawContours(rgb, contornos, -1, (0, 255, 0), 2)

    cv2_imshow(rgb)

    # for cont in contornos:
    #   (x, y, w, h) = cv2.boundingRect(cont)
    #   if h > 150 or w < 60:
    #     continue
    #   elif h < 100 and w < 100:
    #     continue
    #   elif h < 100 or w < 100:
    #     continue
    #   elif w == 181 or w == 182 or w == 183 or w == 184 or w == 185 or w == 120 or w == 119 or w == 186 or w == 236 or w == 346 or w == 118:
    #     continue
    #   elif h == 141 or h == 142 or h == 143 or h == 144:
    #     continue

    #   cut = img[y:y+h, x:x+w]
    #   cv2_imshow(cut)
    #   print(f"Comprimento: {w}, altura: {h}, área: {w*h}, contador: {contador}")
    #   cars.append(cut)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
enter = str(input('Entre com ENTER para continuar')) # célula de armazenamento dos carros e sua contagem
for el in cars:
  cv2_imshow(el)
print(f"A quantidade total de carros identidicados é {len(cars)}")

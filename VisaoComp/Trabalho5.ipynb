# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab.patches import cv2_imshow
from math import floor
import cv2

def getHistogram(img):
  color = ('b', 'g', 'r')

  for i, col in enumerate(color):
    histr = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histr, color=col)
    plt.xlim([0, 256])

  return plt.show()

# %%
drive.mount("/content/drive")
img1 = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/image1.jpg")
soccer = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/soccer.jpg")
cpsoccer = soccer.copy()

cp1 = img1.copy()
# Out:
# Mounted at /content/drive

# %%
# getHistogram(cp1)

for i in range(cp1.shape[0]):
  for j in range(cp1.shape[1]):
    b, g, r = cp1[i, j]
    b1, g1, r1 = cpsoccer[i, j]

    if g > 100 and r < 170 and b < 150:
      cp1[i, j] = cpsoccer[i-70, j+400]
      # cp1[i, j] = cpsoccer[i, j]
    else:
      pass

cv2_imshow(cp1)
# Out:
# <PIL.Image.Image image mode=RGB size=516x720>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
img2 = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/image2.jpg")
cp2 = img2.copy()

jn = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/JN2.png")
acidente = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/acidente.jpg")

print(cp2.shape)

color = ('g', 'b', 'r')

for i in range(cp2.shape[0] // 3, cp2.shape[0]):
    for j in range(0, cp2.shape[1] // 3):
        b, g, r = cp2[i, j]

        if g > 180 and r < 110:
            acidente_i = i - (cp2.shape[0] // 3)
            acidente_j = j - 150

            if acidente_i < acidente.shape[0] and acidente_j < acidente.shape[1]:
                cp2[i, j] = acidente[acidente_i, acidente_j]

for i in range(0, cp2.shape[0]):
  for j in range(cp2.shape[1]//3, cp2.shape[1]):
    b, g, r = cp2[i, j]

    if g > 180 and r < 110:
      jn_i = i - (cp2.shape[0]-150)
      jn_j = j - (cp2.shape[1]+50)

      if jn_i < acidente.shape[0] and acidente_j < acidente.shape[1]:
        cp2[i, j] = jn[jn_i, jn_j]

# cv2_imshow(cp2[0 : cp2.shape[0], cp2.shape[1]//3 : cp2.shape[1]])
cv2_imshow(cp2)
# Out:
# (616, 1100, 3)
# <PIL.Image.Image image mode=RGB size=1100x616>

# %%
img3 = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/image3.jpg")
arq = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/arq.jpg")
fla = cv2.imread("/content/drive/MyDrive/Trabalho5VisComp/fla.png")
cp3 = img3.copy()

cv2_imshow(cp3) # impressão da imagem original

for i in range(0, cp3.shape[0]):
  for j in range(0, cp3.shape[1]):
    b, g, r = cp3[i, j]

    if g > r and g > b:
      # cp3[i, j] = (b, g-50, r-10)
      i_arq = i - 10
      j_arq = j - 10
      cp3[i, j] = arq[i_arq, j_arq]
    elif(g<80 and r>90 and b>90):
      cp3[i, j] = (0, 0, 0)

cv2_imshow(cp3) # impressão da imagem reposicionada dentro de um estádio


for i in range(0, cp3.shape[0]):
  for j in range(0, cp3.shape[1]):
    b, g, r = cp3[i, j]

    if b == 0 and g == 0 and r == 0:

      cp3[i, j] = fla[i, j+100]

cv2_imshow(cp3) # impressão da imagem com o homem em questão com uma camisa de time
print(cp3.shape)
print(fla.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=620x412>
# <PIL.Image.Image image mode=RGB size=620x412>
# <PIL.Image.Image image mode=RGB size=620x412>
# (412, 620, 3)
# (750, 750, 3)
